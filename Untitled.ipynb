# %%
import pandas as pd

# %%
df = pd.read_csv('spIndex.csv')

# %%
df
# Out:
#     Symbol                   Description      Category2  Category3  \
# 0     AAPL                     Apple Inc  Common stocks  Large cap
# 1     MSFT                Microsoft Corp  Common stocks  Large cap
# 2     GOOG          Alphabet Inc Class C  Common stocks  Large cap
# 3    GOOGL          Alphabet Inc Class A  Common stocks  Large cap
# 4     AMZN               Amazon.Com Inc.  Common stocks  Large cap
# ..     ...                           ...            ...        ...
# 498    ALK          Alaska Air Group Inc  Common stocks    Mid cap
# 499    NWL             Newell Brands Inc  Common stocks    Mid cap
# 500    VNO          Vornado Realty Trust          REITs    Mid cap
# 501   TECH               Bio-Techne Corp  Common stocks    Mid cap
# 502    TAP  Molson Coors Brewing Class B  Common stocks  Small cap
#
#                 GICS Sector          Market cap Dividend yield
# 0    Information Technology  $2,242,090,150,920          0.64%
# ...

# %%
symbols = df['Symbol'].tolist()

# %%
names = df['Description'].tolist().sort()
